# %% [markdown]
# <a href="https://colab.research.google.com/github/KulpitchaS/background-generator/blob/main/12_Recurrent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Recurrent Neural Networks
#
# Recurrent neural networks are designed to analyze data consisting of ordered sequences of values. They are useful tools for analyzing temporal changes or other types of sequential data.

# %% [markdown]
# # Global Surface Temperature
#
# For our first example, we will use the global temperature estimate (GISTEMP) from NASA https://data.giss.nasa.gov/gistemp/
#
# * GISTEMP Team, 2023: GISS Surface Temperature Analysis (GISTEMP), version 4. NASA Goddard Institute for Space Studies.
# * Lenssen, N., G. Schmidt, J. Hansen, M. Menne, A. Persin, R. Ruedy, and D. Zyss, 2019: [Improvements in the GISTEMP uncertainty model](https://agupubs.onlinelibrary.wiley.com/doi/10.1029/2018JD029522). J. Geophys. Res. Atmos., 124, no. 12, 6307-6326, doi:10.1029/2018JD029522.

# %%
import pandas as pd

url = 'https://data.giss.nasa.gov/gistemp/tabledata_v4/GLB.Ts+dSST.csv'

# read from CSV file into a pandas data frame
# skip first and last row
df = pd.read_csv(url, skiprows=1, skipfooter=1, engine='python')
df.head()
# Out:
#    Year   Jan   Feb   Mar   Apr   May   Jun   Jul   Aug   Sep   Oct   Nov  \
# 0  1880 -0.18 -0.24 -0.09 -0.16 -0.10 -0.21 -0.18 -0.10 -0.14 -0.23 -0.22
# 1  1881 -0.20 -0.14  0.03  0.05  0.06 -0.19  0.00 -0.04 -0.15 -0.22 -0.19
# 2  1882  0.16  0.14  0.05 -0.17 -0.15 -0.23 -0.16 -0.07 -0.14 -0.23 -0.16
# 3  1883 -0.29 -0.37 -0.12 -0.18 -0.17 -0.08 -0.06 -0.14 -0.21 -0.11 -0.23
# 4  1884 -0.13 -0.08 -0.36 -0.40 -0.34 -0.35 -0.30 -0.28 -0.27 -0.25 -0.33
#
#     Dec   J-D   D-N   DJF   MAM   JJA   SON
# 0 -0.17 -0.17   ***   *** -0.12 -0.17 -0.20
# 1 -0.07 -0.09  -.10  -.17  0.05 -0.08 -0.18
# 2 -0.35 -0.11  -.09   .08 -0.09 -0.16 -0.18
# 3 -0.11 -0.17  -.19  -.34 -0.16 -0.09 -0.18
# 4 -0.31 -0.28  -.27  -.10 -0.36 -0.31 -0.28

# %%
df.tail()
# Out:
#      Year   Jan   Feb   Mar   Apr   May   Jun   Jul   Aug   Sep   Oct   Nov  \
# 139  2019  0.94  0.95  1.17  1.02  0.85  0.90  0.94  0.95  0.93  1.00  0.99
# 140  2020  1.17  1.24  1.17  1.13  1.02  0.91  0.89  0.87  0.98  0.88  1.10
# 141  2021  0.81  0.64  0.89  0.75  0.79  0.84  0.92  0.82  0.92  0.99  0.94
# 142  2022  0.91  0.89  1.05  0.84  0.84  0.92  0.94  0.95  0.89  0.96  0.73
# 143  2023  0.88  0.98  1.22  1.00  0.93  1.08  1.19  1.20  1.48  1.34  1.43
#
#       Dec   J-D   D-N   DJF   MAM   JJA   SON
# 139  1.10  0.98   .96   .94  1.01  0.93  0.97
# 140  0.80  1.01  1.04  1.17  1.11  0.89  0.99
# 141  0.86  0.85   .84   .75  0.81  0.86  0.95
# 142  0.80  0.89   .90   .89  0.91  0.94  0.86
# 143  1.35  1.17  1.13   .89  1.05  1.16  1.41

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 19 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Year    144 non-null    int64
#  1   Jan     144 non-null    float64
#  2   Feb     144 non-null    float64
#  3   Mar     144 non-null    float64
#  4   Apr     144 non-null    float64
#  5   May     144 non-null    float64
#  6   Jun     144 non-null    float64
#  7   Jul     144 non-null    float64
#  8   Aug     144 non-null    float64
#  9   Sep     144 non-null    float64
#  10  Oct     144 non-null    float64
#  11  Nov     144 non-null    float64
#  12  Dec     144 non-null    float64
#  13  J-D     144 non-null    float64
#  14  D-N     144 non-null    object
#  15  DJF     144 non-null    object
#  16  MAM     144 non-null    float64
#  17  JJA     144 non-null    float64
#  18  SON     144 non-null    float64
# dtypes: float64(16), int64(1), object(2)
# memory usage: 21.5+ KB

# %% [markdown]
# The data table contains temperature anomalies by month for the last 144 years. Plotting the table allows us to visualize how the present day stands out in history.

# %%
months = 'Jan Feb Mar Apr May Jun Jul Aug Sep Oct Nov Dec'.split()
temp = df[months].to_numpy()

# %%
import matplotlib.pyplot as plt

plt.imshow(temp, aspect=1/12, extent=[0, 11, 2024, 1880])
cb = plt.colorbar()
cb.ax.invert_yaxis()
cb.set_label('global surface temperature change ($^{o}C$)')
plt.xticks(range(12), months)
plt.show()

# %% [markdown]
# Let us flatten the data to put the timeline into a one-dimensional array.

# %%
temp1 = temp.flatten()
length = len(temp1)

# %%
import numpy as np

xaxis = np.arange(1880, 2024, 1/12)
plt.plot(xaxis, temp1)
plt.xlabel('year')
plt.ylabel('global surface temperature change ($^{\circ}C$)')
plt.show()

# %% [markdown]
# We can apply a running mean filter to smooth the data for better visualization.

# %%
def running_mean(x, radius):
    'apply a box filter for smoothing the input'
    cumsum = np.cumsum(np.pad(x, (radius, 0), 'edge'))
    return (cumsum[radius:] - cumsum[:-radius])/radius


# smooth over three years = 36 months
temp_smooth = running_mean(temp1, 36)

# %%
plt.plot(xaxis, temp1, alpha=0.5)
plt.plot(xaxis, temp_smooth, color='b')
plt.xlabel('year')
plt.ylabel('global surface temperature change ($^{o}C$)')
plt.show()

# %% [markdown]
# ## Making Predictions
#
# Learning the data pattern implies the ability to make predictions. We will try to learn how to predict global temperature changes using previous values.

# %% [markdown]
# To simplify further processing, let us first scale the data to the range from -1 to 1.

# %%
from sklearn.preprocessing import MinMaxScaler

# add a dimension of one
temp2 = np.expand_dims(temp_smooth, 1)
# set the range
scaler = MinMaxScaler((-1, 1)).fit(temp2)
temp_scaled = scaler.transform(temp2)
temp_scaled
# Out:
# array([[-0.59637974],
#        [-0.59869054],
#        [-0.59522434],
#        ...,
#        [ 0.96610822],
#        [ 0.97881764],
#        [ 1.        ]])

# %% [markdown]
# Next, we break the data into sliding windows with 121 values in each window. For better training, we randomly shuffle the windows.

# %%
import random

time = 120  # 10 years

x = []
for n in range(time, length):
    x.append(temp_scaled[n-time:n+1, :])

random.seed(2024)
random.shuffle(x)
x = np.array(x)
x.shape
# Out:
# (1608, 121, 1)

# %% [markdown]
# We are going to train our machine-learning model to predict the 121st value from the previous 120 values, representing 10 years of global temperature measurements.

# %%
X = x[:, :time, :]
y = x[:, time, :]

X.shape, y.shape
# Out:
# ((1608, 120, 1), (1608, 1))

# %%
from tensorflow.keras.utils import set_random_seed

# for reproducibility
set_random_seed(2024)
np.random.seed(2024)

# %% [markdown]
# Our first attempt of a predictive model will be a fully-connected neural network with one hidden layer.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense

fmodel = Sequential()
fmodel.add(Input((time,)))
fmodel.add(Dense(5, activation='tanh'))
fmodel.add(Dense(1))
fmodel.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 5)                 605
#
#  dense_1 (Dense)             (None, 1)                 6
#
# =================================================================
# Total params: 611 (2.39 KB)
# Trainable params: 611 (2.39 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# In the hidden layer, the corresponding equation is
#
# $\mathbf{h} = t\left(\mathbf{A}^T\,\mathbf{x}+\mathbf{b}\right)\;,$
#
# where $t$ stands for the hyperbolic tangent function $\tanh$, $\mathbf{A}$ is a $120 \times 5$ matrix, and $\mathbf{b}$ is a vector of size 5.
#
# In the output layer, the equation is
#
# $y = \mathbf{a}^T\,\mathbf{h} + b\;,$
#
# with the scalar intercept $b$ and the slope $\mathbf{a}$ as a vector of size 5.
#
# Altogether, the model has $120 \times 5 + 5 + 5 + 1 = 611$ parameters.

# %%
epochs = 25

fmodel.compile(optimizer='adam', loss='mse')
fit = fmodel.fit(X, y, epochs=epochs, batch_size=12, validation_split=0.1)
# Out:
# Epoch 1/25
# 121/121 [==============================] - 3s 4ms/step - loss: 0.0345 - val_loss: 0.0055
# Epoch 2/25
# 121/121 [==============================] - 0s 3ms/step - loss: 0.0045 - val_loss: 0.0028
# Epoch 3/25
# 121/121 [==============================] - 0s 3ms/step - loss: 0.0027 - val_loss: 0.0025
# Epoch 4/25
# 121/121 [==============================] - 0s 3ms/step - loss: 0.0022 - val_loss: 0.0015
# Epoch 5/25
# 121/121 [==============================] - 0s 3ms/step - loss: 0.0019 - val_loss: 0.0013
# Epoch 6/25
# 121/121 [==============================] - 0s 3ms/step - loss: 0.0015 - val_loss: 0.0011
# Epoch 7/25
# 121/121 [==============================] - 0s 3ms/step - loss: 0.0015 - val_loss: 9.4918e-04
# Epoch 8/25
# 121/121 [==============================] - 0s 3ms/step - loss: 0.0012 - val_loss: 8.9383e-04
# Epoch 9/25
# 121/121 [==============================] - 0s 3ms/step - loss: 0.0014 - val_loss: 9.9712e-04
# Epoch 10/25
# 121/121 [==============================] - 0s 3ms/step - loss: 0.0010 - val_loss: 8.2269e-04
# Epoch 11/25
# 121/121 [==============================] - 0s 3ms/step - loss: 0.0012 - val_loss: 7.0298e-04
# Epoch 12/25
# 121/121 [==============================] - 0s 3ms/step - loss: 9.2568e-04 - val_loss: 6.8331e-04
# Epoch 13/25
# 121/121 [==============================] - 0s 3ms/step - loss: 9.0200e-04 - val_loss: 6.8183e-04
# Epoch 14/25
# 121/121 [==============================] - 0s 3ms/step - loss: 8.7006e-04 - val_loss: 5.7516e-04
# Epoch 15/25
# 121/121 [==============================] - 0s 3ms/step - loss: 7.1741e-04 - val_loss: 5.2037e-04
# Epoch 16/25
# 121/121 [==============================] - 0s 3ms/step - loss: 8.2065e-04 - val_loss: 9.4197e-04
# Epoch 17/25
# 121/121 [==============================] - 0s 3ms/step - loss: 7.2657e-04 - val_loss: 5.6824e-04
# Epoch 18/25
# 121/121 [==============================] - 0s 3ms/step - loss: 6.8935e-04 - val_loss: 5.5992e-04
# Epoch 19/25
# 121/121 [==============================] - 0s 3ms/step - loss: 6.9615e-04 - val_loss: 4.9123e-04
# Epoch 20/25
# 121/121 [==============================] - 0s 3ms/step - loss: 6.3121e-04 - val_loss: 4.0505e-04
# Epoch 21/25
# 121/121 [==============================] - 0s 3ms/step - loss: 6.1919e-04 - val_loss: 4.6120e-04
# Epoch 22/25
# 121/121 [==============================] - 0s 3ms/step - loss: 5.7833e-04 - val_loss: 3.6713e-04
# Epoch 23/25
# 121/121 [==============================] - 0s 3ms/step - loss: 8.1861e-04 - val_loss: 6.3877e-04
# Epoch 24/25
# 121/121 [==============================] - 0s 3ms/step - loss: 5.3588e-04 - val_loss: 3.8602e-04
# Epoch 25/25
# 121/121 [==============================] - 0s 3ms/step - loss: 8.6439e-04 - val_loss: 4.5507e-04

# %%
def plot_loss(fit, epochs):
    iterations = np.arange(1, epochs+1)
    plt.plot(iterations, fit.history['loss'], label='loss')
    plt.plot(iterations, fit.history['val_loss'], label='validation loss')
    plt.legend()
    plt.xticks(iterations[::epochs//10])
    plt.xlabel('Epochs')
    plt.show()


plot_loss(fit, epochs)

# %% [markdown]
# The model works well, but it is not optimal because it fails to consider the data's sequential nature. Let us see if we can improve performance using a recurrent neural network.

# %% [markdown]
# ## Simple RNN
#
# We will first try a classic formulation of a recurrent neural network, implemented in Keras as <code>simpleRNN</code>.

# %%
from tensorflow.keras.layers import SimpleRNN

rmodel = Sequential()
rmodel.add(SimpleRNN(24, input_shape=(time, 1)))
rmodel.add(Dense(1))
rmodel.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 24)                624
#
#  dense_2 (Dense)             (None, 1)                 25
#
# =================================================================
# Total params: 649 (2.54 KB)
# Trainable params: 649 (2.54 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# The <tt>simpleRNN</tt> layer is based on the following equation:
#
# $\mathbf{h}_n = t\left(\mathbf{A}^T\,\mathbf{h}_{n-1}  + \mathbf{b} + \mathbf{c}^T\,x_n\right)\;,$
#
# where $\mathbf{A}$ is a $24 \times 24$ matrix, and $\mathbf{b}$ is a column-vector of size 24, and $\mathbf{c}$ is a row-vector of size 24. The sequence of hidden state vectors $\mathbf{h}_n$ is initialized with a zero vector. The model represents a recursive computation that tries to capture the sequential pattern.
#
# The output layer is analogous to the previous case:
#
# $x_{N+1} = \mathbf{a}^T\,\mathbf{h}_N + b\;,$
#
# Altogether, the model has $24 \times 24 + 24 + 24 + 24 + 1 = 649$ parameters.

# %% [markdown]
# Note that the number of parameters does not depend on the data size.

# %%
24*24+24*3+1
# Out:
# 649

# %%
epochs = 25

rmodel.compile(optimizer='adam', loss='mse')
fit = rmodel.fit(X, y, epochs=epochs, batch_size=12, validation_split=0.1)
# Out:
# Epoch 1/25
# 121/121 [==============================] - 10s 73ms/step - loss: 0.0144 - val_loss: 9.6617e-04
# Epoch 2/25
# 121/121 [==============================] - 9s 73ms/step - loss: 8.1030e-04 - val_loss: 5.4104e-04
# Epoch 3/25
# 121/121 [==============================] - 8s 69ms/step - loss: 5.0024e-04 - val_loss: 3.7657e-04
# Epoch 4/25
# 121/121 [==============================] - 7s 61ms/step - loss: 3.8566e-04 - val_loss: 3.1596e-04
# Epoch 5/25
# 121/121 [==============================] - 8s 69ms/step - loss: 3.2190e-04 - val_loss: 2.6731e-04
# Epoch 6/25
# 121/121 [==============================] - 8s 66ms/step - loss: 2.7362e-04 - val_loss: 2.6631e-04
# Epoch 7/25
# 121/121 [==============================] - 8s 65ms/step - loss: 2.4134e-04 - val_loss: 2.0184e-04
# Epoch 8/25
# 121/121 [==============================] - 9s 71ms/step - loss: 2.1334e-04 - val_loss: 1.8463e-04
# Epoch 9/25
# 121/121 [==============================] - 8s 68ms/step - loss: 1.8639e-04 - val_loss: 1.6501e-04
# Epoch 10/25
# 121/121 [==============================] - 7s 62ms/step - loss: 1.8097e-04 - val_loss: 1.5544e-04
# Epoch 11/25
# 121/121 [==============================] - 8s 69ms/step - loss: 1.6253e-04 - val_loss: 1.5291e-04
# Epoch 12/25
# 121/121 [==============================] - 8s 62ms/step - loss: 1.5214e-04 - val_loss: 1.6904e-04
# Epoch 13/25
# 121/121 [==============================] - 8s 65ms/step - loss: 1.4151e-04 - val_loss: 1.2511e-04
# Epoch 14/25
# 121/121 [==============================] - 8s 68ms/step - loss: 1.3441e-04 - val_loss: 1.4404e-04
# Epoch 15/25
# 121/121 [==============================] - 7s 61ms/step - loss: 1.2528e-04 - val_loss: 1.2119e-04
# Epoch 16/25
# 121/121 [==============================] - 8s 68ms/step - loss: 1.1389e-04 - val_loss: 1.1118e-04
# Epoch 17/25
# 121/121 [==============================] - 8s 69ms/step - loss: 1.0658e-04 - val_loss: 1.3354e-04
# Epoch 18/25
# 121/121 [==============================] - 7s 59ms/step - loss: 1.0295e-04 - val_loss: 9.3486e-05
# Epoch 19/25
# 121/121 [==============================] - 8s 68ms/step - loss: 1.0699e-04 - val_loss: 9.6232e-05
# Epoch 20/25
# 121/121 [==============================] - 8s 67ms/step - loss: 9.6975e-05 - val_loss: 1.3946e-04
# Epoch 21/25
# 121/121 [==============================] - 7s 60ms/step - loss: 9.0457e-05 - val_loss: 9.4281e-05
# Epoch 22/25
# 121/121 [==============================] - 8s 70ms/step - loss: 9.1528e-05 - val_loss: 8.3381e-05
# Epoch 23/25
# 121/121 [==============================] - 8s 67ms/step - loss: 8.2894e-05 - val_loss: 9.1832e-05
# Epoch 24/25
# 121/121 [==============================] - 7s 60ms/step - loss: 8.0321e-05 - val_loss: 8.9665e-05
# Epoch 25/25
# 121/121 [==============================] - 8s 67ms/step - loss: 8.0937e-05 - val_loss: 6.9908e-05

# %%
plot_loss(fit, epochs)

# %% [markdown]
# The model's convergence has improved but can be enhanced further with a more robust method.

# %% [markdown]
# ## <div style="color:red">Task 1</div>
#
# Let us take a look inside the black box. We can extract the model weights and examine them.

# %%
# weights from the SimpleRNN layer
c, A, b = rmodel.layers[0].get_weights()
A.shape, b.shape, c.shape
# Out:
# ((24, 24), (24,), (1, 24))

# %%
plt.figure(figsize=(20,6))
plt.imshow(A)
plt.title('A Weights Matrix Grid')
cbar = plt.colorbar()

# %%
plt.figure(figsize=(20,6))
plt.plot(A)
plt.title('A Weights Vector Components')
plt.grid(visible=True)

# %%
plt.hist(A)
plt.title('A weights Histogram')
# Out:
# Text(0.5, 1.0, 'A weights Histogram')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,6))
plt.plot(b,'o-')
plt.title('B Weights - Column Vector')
plt.grid(visible=True)

# %%
plt.hist(b)
plt.title('B weights - Column Vector - Histogram')
# Out:
# Text(0.5, 1.0, 'B weights - Column Vector - Histogram')

# %%
plt.plot(c[0],'o-')
plt.title('C weights - Row Vector')
plt.grid(visible=True)

# %%
plt.hist(c[0])
plt.title('C weights - Row Vector - Histogram')
# Out:
# Text(0.5, 1.0, 'C weights - Row Vector - Histogram')

# %% [markdown]
# Plot the weights $\mathbf{A}$, $\mathbf{b}$, and $\mathbf{c}$ and try to see if they have any recognizable patterns.

# %% [markdown]
# ## LSTM
#
# LSTM stands for Long Short-Term Memory. It is a famous network design focused on capturing both immediate (short-term) dependencies, as in <code>SimpleRNN</code>, and longer-term trends.
#
# * Hochreiter, S. and Schmidhuber, J., 1997. [Long short-term memory](https://ieeexplore.ieee.org/abstract/document/6795963). Neural computation, 9(8), pp.1735-1780.
#
# Its application is similar.

# %%
from tensorflow.keras.layers import LSTM

lmodel = Sequential()
lmodel.add(LSTM(12, input_shape=(time, 1)))
lmodel.add(Dense(1))
lmodel.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 12)                672
#
#  dense_3 (Dense)             (None, 1)                 13
#
# =================================================================
# Total params: 685 (2.68 KB)
# Trainable params: 685 (2.68 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ![](https://miro.medium.com/v2/resize:fit:720/format:webp/1*yo6sBAs6NUtNI0a16ZqZKQ.png)

# %% [markdown]
# If <code>SimpleRNN</code> maintains only one sequence of hidden-state vectors $\mathbf{h}_n$, LSTM tracks two sequences for short memory and long memory. Its action can be expressed with a sequence of equations or a diagram.

# %% [markdown]
# ![](https://miro.medium.com/v2/resize:fit:720/format:webp/1*Zrht4QBK5_hAxif17ED4ew.png)
#
# https://towardsdatascience.com/lstm-recurrent-neural-networks-how-to-teach-a-network-to-remember-the-past-55e54c2ff22e

# %%
epochs = 30

lmodel.compile(optimizer='adam', loss='mse')
fit = lmodel.fit(X, y, epochs=epochs, batch_size=12, validation_split=0.1)
# Out:
# Epoch 1/30
# 121/121 [==============================] - 3s 10ms/step - loss: 0.0946 - val_loss: 0.0038
# Epoch 2/30
# 121/121 [==============================] - 1s 8ms/step - loss: 0.0030 - val_loss: 0.0019
# Epoch 3/30
# 121/121 [==============================] - 1s 9ms/step - loss: 0.0019 - val_loss: 0.0015
# Epoch 4/30
# 121/121 [==============================] - 1s 7ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 5/30
# 121/121 [==============================] - 1s 7ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 6/30
# 121/121 [==============================] - 1s 7ms/step - loss: 0.0012 - val_loss: 9.9495e-04
# Epoch 7/30
# 121/121 [==============================] - 1s 6ms/step - loss: 9.6984e-04 - val_loss: 8.9114e-04
# Epoch 8/30
# 121/121 [==============================] - 1s 8ms/step - loss: 8.3072e-04 - val_loss: 8.2801e-04
# Epoch 9/30
# 121/121 [==============================] - 1s 7ms/step - loss: 7.1971e-04 - val_loss: 7.2663e-04
# Epoch 10/30
# 121/121 [==============================] - 1s 6ms/step - loss: 6.5076e-04 - val_loss: 6.2332e-04
# Epoch 11/30
# 121/121 [==============================] - 1s 6ms/step - loss: 5.6870e-04 - val_loss: 5.8074e-04
# Epoch 12/30
# 121/121 [==============================] - 1s 6ms/step - loss: 5.1975e-04 - val_loss: 5.9895e-04
# Epoch 13/30
# 121/121 [==============================] - 1s 7ms/step - loss: 4.8112e-04 - val_loss: 5.1273e-04
# Epoch 14/30
# 121/121 [==============================] - 1s 6ms/step - loss: 4.5010e-04 - val_loss: 5.0817e-04
# Epoch 15/30
# 121/121 [==============================] - 1s 7ms/step - loss: 4.1516e-04 - val_loss: 4.1158e-04
# Epoch 16/30
# 121/121 [==============================] - 1s 8ms/step - loss: 3.8733e-04 - val_loss: 4.2360e-04
# Epoch 17/30
# 121/121 [==============================] - 1s 9ms/step - loss: 3.6124e-04 - val_loss: 4.8619e-04
# Epoch 18/30
# 121/121 [==============================] - 1s 7ms/step - loss: 3.4138e-04 - val_loss: 3.5737e-04
# Epoch 19/30
# 121/121 [==============================] - 1s 7ms/step - loss: 3.4028e-04 - val_loss: 3.0834e-04
# Epoch 20/30
# 121/121 [==============================] - 1s 7ms/step - loss: 3.0265e-04 - val_loss: 3.6591e-04
# Epoch 21/30
# 121/121 [==============================] - 1s 6ms/step - loss: 2.8974e-04 - val_loss: 2.8438e-04
# Epoch 22/30
# 121/121 [==============================] - 1s 7ms/step - loss: 2.7984e-04 - val_loss: 2.9417e-04
# Epoch 23/30
# 121/121 [==============================] - 1s 7ms/step - loss: 2.5623e-04 - val_loss: 2.3615e-04
# Epoch 24/30
# 121/121 [==============================] - 1s 7ms/step - loss: 2.4121e-04 - val_loss: 2.2082e-04
# Epoch 25/30
# 121/121 [==============================] - 1s 7ms/step - loss: 2.1926e-04 - val_loss: 2.0680e-04
# Epoch 26/30
# 121/121 [==============================] - 1s 7ms/step - loss: 2.1943e-04 - val_loss: 2.1419e-04
# Epoch 27/30
# 121/121 [==============================] - 1s 7ms/step - loss: 2.2800e-04 - val_loss: 2.5762e-04
# Epoch 28/30
# 121/121 [==============================] - 1s 7ms/step - loss: 2.0252e-04 - val_loss: 1.7625e-04
# Epoch 29/30
# 121/121 [==============================] - 1s 7ms/step - loss: 1.9339e-04 - val_loss: 1.9278e-04
# Epoch 30/30
# 121/121 [==============================] - 1s 8ms/step - loss: 1.8134e-04 - val_loss: 2.0176e-04

# %%
plot_loss(fit, epochs)

# %% [markdown]
# ## Testing Model
#
# First, we can test how well the model predicts existing data.

# %%
# select overlapping 10-year windows
x = []
for n in range(time, length):
    x.append(temp_scaled[n-time:n, :])
x = np.array(x)

# make a prediction and unscale it
yp = scaler.inverse_transform(lmodel.predict(x))
# Out:
# 51/51 [==============================] - 1s 4ms/step

# %%
plt.plot(xaxis, temp_smooth, label='actual')
plt.plot(np.arange(1890, 2024, 1/12), yp, label='prediction')
plt.legend()
plt.xlabel('year')
plt.ylabel('global surface temperature change ($^{o}C$)')
plt.show()

# %% [markdown]
# In a more challenging test, let us use ten years of observations before 2016 (the time of the Paris Climate Accords) to predict global temperature changes in the future.

# %%
first = (2016-1880)*12
temp_last = temp_scaled[first-time:first, :]
preds = []
for n in range(first, length):
    # make prediction
    pred = lmodel.predict(np.expand_dims(temp_last, 0), verbose=0)
    # append it to the sliding window
    temp_last = np.append(temp_last[1:, :], pred, axis=0)
    # save it in an array
    preds.append(pred[0])
# unscale the predictions
preds = scaler.inverse_transform(np.array(preds))

# %%
plt.plot(xaxis, temp_smooth, label='actual')
plt.plot(np.arange(2016, 2024, 1/12), preds, label='prediction')
plt.legend()
plt.xlabel('year')
plt.ylabel('global surface temperature change ($^{o}C$)')
plt.show()

# %% [markdown]
# We can see that our model overestimated the actual temperature increase.

# %% [markdown]
# ### Detrending
#
# Our model assumes a stationary behavior inconsistent with the temperature data. To make the data more stationary, we can remove the overall trend by using linear regression with nonlinear terms.

# %%
from sklearn.linear_model import LinearRegression

# year and year squared
xx2 = np.stack((xaxis, xaxis**2)).transpose()

# fitting a parabola
LR = LinearRegression().fit(xx2, temp1)

# extracting a parabolic trend
trend = LR.predict(xx2)

# %%
plt.plot(xaxis, temp1, alpha=0.5)
plt.plot(xaxis, trend, label='trend')
plt.xlabel('year')
plt.ylabel('global surface temperature change ($^{o}C$)')
plt.legend()
plt.show()

# %%
detrend = temp1 - trend

plt.plot(xaxis, detrend)
plt.xlabel('year')
plt.ylabel('global surface temperature change ($^{o}C$)')
plt.title('Detrended')
plt.show()

# %% [markdown]
# ## <div style="color:red">Task 2</div>
#
# Repeat the analysis (starting with smoothing) for the data with the removed trend and see if the patterns become more predictable.

# %%
detrend_smooth = running_mean(detrend, 36)

# %%
plt.plot(xaxis, detrend, alpha=0.5)
plt.plot(xaxis, temp_smooth, color='b')
plt.xlabel('year')
plt.ylabel('global surface temperature change ($^{o}C$)')
plt.show()

# %%
# NN
from sklearn.preprocessing import MinMaxScaler
import random

# Scale data:(same as earlier)
# add a dimension of one
temp2 = np.expand_dims(detrend_smooth, 1)
# set the range
scaler = MinMaxScaler((-1, 1)).fit(temp2)
temp_scaled = scaler.transform(temp2)

# shuffle: (same as earlier)
time = 120  # 10 years

x = []
for n in range(time, length):
    x.append(temp_scaled[n-time:n+1, :])

random.seed(2024)
random.shuffle(x)
x = np.array(x)
x.shape
# Out:
# (1608, 121, 1)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense

fmodel = Sequential()
fmodel.add(Input((time,)))
fmodel.add(Dense(5, activation='tanh'))
fmodel.add(Dense(1))
fmodel.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 5)                 605
#
#  dense_5 (Dense)             (None, 1)                 6
#
# =================================================================
# Total params: 611 (2.39 KB)
# Trainable params: 611 (2.39 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
epochs = 25

fmodel.compile(optimizer='adam', loss='mse')
fit = fmodel.fit(X, y, epochs=epochs, batch_size=12, validation_split=0.1)
# Out:
# Epoch 1/25
# 121/121 [==============================] - 1s 4ms/step - loss: 0.0550 - val_loss: 0.0116
# Epoch 2/25
# 121/121 [==============================] - 0s 3ms/step - loss: 0.0093 - val_loss: 0.0063
# Epoch 3/25
# 121/121 [==============================] - 0s 3ms/step - loss: 0.0047 - val_loss: 0.0030
# Epoch 4/25
# 121/121 [==============================] - 0s 3ms/step - loss: 0.0030 - val_loss: 0.0020
# Epoch 5/25
# 121/121 [==============================] - 0s 3ms/step - loss: 0.0024 - val_loss: 0.0017
# Epoch 6/25
# 121/121 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0014
# Epoch 7/25
# 121/121 [==============================] - 0s 3ms/step - loss: 0.0018 - val_loss: 0.0013
# Epoch 8/25
# 121/121 [==============================] - 0s 3ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 9/25
# 121/121 [==============================] - 0s 4ms/step - loss: 0.0013 - val_loss: 9.9706e-04
# Epoch 10/25
# 121/121 [==============================] - 0s 4ms/step - loss: 0.0012 - val_loss: 0.0010
# Epoch 11/25
# 121/121 [==============================] - 0s 4ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 12/25
# 121/121 [==============================] - 1s 4ms/step - loss: 0.0010 - val_loss: 8.0780e-04
# Epoch 13/25
# 121/121 [==============================] - 0s 3ms/step - loss: 9.0206e-04 - val_loss: 8.8713e-04
# Epoch 14/25
# 121/121 [==============================] - 0s 3ms/step - loss: 9.5842e-04 - val_loss: 7.7393e-04
# Epoch 15/25
# 121/121 [==============================] - 0s 3ms/step - loss: 8.7440e-04 - val_loss: 6.5879e-04
# Epoch 16/25
# 121/121 [==============================] - 0s 3ms/step - loss: 7.6024e-04 - val_loss: 5.7100e-04
# Epoch 17/25
# 121/121 [==============================] - 0s 3ms/step - loss: 7.1463e-04 - val_loss: 6.0797e-04
# Epoch 18/25
# 121/121 [==============================] - 0s 3ms/step - loss: 7.1704e-04 - val_loss: 5.8753e-04
# Epoch 19/25
# 121/121 [==============================] - 0s 3ms/step - loss: 6.3877e-04 - val_loss: 5.5406e-04
# Epoch 20/25
# 121/121 [==============================] - 0s 3ms/step - loss: 6.8553e-04 - val_loss: 5.5206e-04
# Epoch 21/25
# 121/121 [==============================] - 0s 3ms/step - loss: 6.6956e-04 - val_loss: 5.3328e-04
# Epoch 22/25
# 121/121 [==============================] - 0s 3ms/step - loss: 6.0428e-04 - val_loss: 4.6904e-04
# Epoch 23/25
# 121/121 [==============================] - 0s 3ms/step - loss: 6.1005e-04 - val_loss: 4.2915e-04
# Epoch 24/25
# 121/121 [==============================] - 0s 3ms/step - loss: 5.5602e-04 - val_loss: 4.0184e-04
# Epoch 25/25
# 121/121 [==============================] - 0s 3ms/step - loss: 5.9704e-04 - val_loss: 3.8438e-04

# %%
plot_loss(fit, epochs)

# %%
# RNN
from tensorflow.keras.layers import SimpleRNN

rmodel = Sequential()
rmodel.add(SimpleRNN(24, input_shape=(time, 1)))
rmodel.add(Dense(1))
rmodel.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_1 (SimpleRNN)    (None, 24)                624
#
#  dense_6 (Dense)             (None, 1)                 25
#
# =================================================================
# Total params: 649 (2.54 KB)
# Trainable params: 649 (2.54 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
epochs = 25

rmodel.compile(optimizer='adam', loss='mse')
fit = rmodel.fit(X, y, epochs=epochs, batch_size=12, validation_split=0.1)
# Out:
# Epoch 1/25
# 121/121 [==============================] - 9s 70ms/step - loss: 0.2678 - val_loss: 0.0046
# Epoch 2/25
# 121/121 [==============================] - 7s 59ms/step - loss: 0.0030 - val_loss: 0.0019
# Epoch 3/25
# 121/121 [==============================] - 8s 67ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 4/25
# 121/121 [==============================] - 8s 67ms/step - loss: 9.7376e-04 - val_loss: 8.6997e-04
# Epoch 5/25
# 121/121 [==============================] - 7s 58ms/step - loss: 7.9013e-04 - val_loss: 7.4839e-04
# Epoch 6/25
# 121/121 [==============================] - 8s 68ms/step - loss: 6.7355e-04 - val_loss: 6.3694e-04
# Epoch 7/25
# 121/121 [==============================] - 8s 68ms/step - loss: 6.0264e-04 - val_loss: 5.7592e-04
# Epoch 8/25
# 121/121 [==============================] - 7s 62ms/step - loss: 5.3296e-04 - val_loss: 5.2061e-04
# Epoch 9/25
# 121/121 [==============================] - 9s 70ms/step - loss: 4.7649e-04 - val_loss: 4.8960e-04
# Epoch 10/25
# 121/121 [==============================] - 9s 72ms/step - loss: 4.7512e-04 - val_loss: 4.4347e-04
# Epoch 11/25
# 121/121 [==============================] - 7s 61ms/step - loss: 4.2129e-04 - val_loss: 4.1423e-04
# Epoch 12/25
# 121/121 [==============================] - 8s 69ms/step - loss: 4.0155e-04 - val_loss: 4.4638e-04
# Epoch 13/25
# 121/121 [==============================] - 9s 72ms/step - loss: 3.8410e-04 - val_loss: 3.5435e-04
# Epoch 14/25
# 121/121 [==============================] - 7s 61ms/step - loss: 3.5112e-04 - val_loss: 3.6115e-04
# Epoch 15/25
# 121/121 [==============================] - 8s 68ms/step - loss: 3.4254e-04 - val_loss: 3.4688e-04
# Epoch 16/25
# 121/121 [==============================] - 8s 68ms/step - loss: 3.2829e-04 - val_loss: 3.4287e-04
# Epoch 17/25
# 121/121 [==============================] - 7s 60ms/step - loss: 3.1790e-04 - val_loss: 3.1325e-04
# Epoch 18/25
# 121/121 [==============================] - 8s 68ms/step - loss: 2.9575e-04 - val_loss: 3.1165e-04
# Epoch 19/25
# 121/121 [==============================] - 8s 66ms/step - loss: 3.0812e-04 - val_loss: 3.2915e-04
# Epoch 20/25
# 121/121 [==============================] - 8s 62ms/step - loss: 2.8853e-04 - val_loss: 3.1266e-04
# Epoch 21/25
# 121/121 [==============================] - 8s 68ms/step - loss: 2.9089e-04 - val_loss: 2.5541e-04
# Epoch 22/25
# 121/121 [==============================] - 7s 61ms/step - loss: 2.6916e-04 - val_loss: 2.8654e-04
# Epoch 23/25
# 121/121 [==============================] - 8s 66ms/step - loss: 2.6752e-04 - val_loss: 2.4645e-04
# Epoch 24/25
# 121/121 [==============================] - 8s 69ms/step - loss: 2.4660e-04 - val_loss: 2.9831e-04
# Epoch 25/25
# 121/121 [==============================] - 7s 60ms/step - loss: 2.4096e-04 - val_loss: 2.4070e-04

# %%
plot_loss(fit, epochs)

# %%
# Weights for comparison to task 1
# weights from the SimpleRNN layer
c, A, b = rmodel.layers[0].get_weights()
A.shape, b.shape, c.shape
# Out:
# ((24, 24), (24,), (1, 24))

# %%
plt.figure(figsize=(6,6))
plt.imshow(A)
plt.title('A Weights Matrix Grid')
cbar = plt.colorbar()

# %%
plt.figure(figsize=(16,6))
plt.plot(A)
plt.title('A Weights Vector Components')
plt.grid(visible=True)

# %%
plt.figure(figsize=(6,6))
plt.hist(A)
plt.title('A weights Histogram')
# Out:
# Text(0.5, 1.0, 'A weights Histogram')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6,6))
plt.plot(b,'o-')
plt.title('B Weights - Column Vector')
plt.grid(visible=True)

# %%
plt.figure(figsize=(6,6))
plt.hist(b)
plt.title('B weights - Column Vector - Histogram')
# Out:
# Text(0.5, 1.0, 'B weights - Column Vector - Histogram')

# %%
plt.figure(figsize=(6,6))
plt.plot(c[0],'o-')
plt.title('C weights - Row Vector')
plt.grid(visible=True)

# %%
plt.figure(figsize=(6,6))
plt.hist(c[0])
plt.title('C weights - Row Vector - Histogram')
# Out:
# Text(0.5, 1.0, 'C weights - Row Vector - Histogram')

# %%
# LSTM Model
from tensorflow.keras.layers import LSTM

lmodel = Sequential()
lmodel.add(LSTM(12, input_shape=(time, 1)))
lmodel.add(Dense(1))
lmodel.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, 12)                672
#
#  dense_7 (Dense)             (None, 1)                 13
#
# =================================================================
# Total params: 685 (2.68 KB)
# Trainable params: 685 (2.68 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
epochs = 30

lmodel.compile(optimizer='adam', loss='mse')
fit = lmodel.fit(X, y, epochs=epochs, batch_size=12, validation_split=0.1)
# Out:
# Epoch 1/30
# 121/121 [==============================] - 3s 11ms/step - loss: 0.0231 - val_loss: 0.0037
# Epoch 2/30
# 121/121 [==============================] - 1s 7ms/step - loss: 0.0025 - val_loss: 0.0014
# Epoch 3/30
# 121/121 [==============================] - 1s 6ms/step - loss: 0.0012 - val_loss: 8.7098e-04
# Epoch 4/30
# 121/121 [==============================] - 1s 7ms/step - loss: 8.7247e-04 - val_loss: 7.7097e-04
# Epoch 5/30
# 121/121 [==============================] - 1s 7ms/step - loss: 7.8417e-04 - val_loss: 7.4838e-04
# Epoch 6/30
# 121/121 [==============================] - 1s 7ms/step - loss: 6.8855e-04 - val_loss: 6.7982e-04
# Epoch 7/30
# 121/121 [==============================] - 1s 7ms/step - loss: 6.1823e-04 - val_loss: 6.1984e-04
# Epoch 8/30
# 121/121 [==============================] - 1s 6ms/step - loss: 5.5493e-04 - val_loss: 6.0519e-04
# Epoch 9/30
# 121/121 [==============================] - 1s 8ms/step - loss: 5.1282e-04 - val_loss: 5.4795e-04
# Epoch 10/30
# 121/121 [==============================] - 1s 9ms/step - loss: 4.9600e-04 - val_loss: 5.0194e-04
# Epoch 11/30
# 121/121 [==============================] - 1s 8ms/step - loss: 4.4052e-04 - val_loss: 4.7301e-04
# Epoch 12/30
# 121/121 [==============================] - 1s 6ms/step - loss: 4.1522e-04 - val_loss: 4.8209e-04
# Epoch 13/30
# 121/121 [==============================] - 1s 7ms/step - loss: 3.9042e-04 - val_loss: 3.8946e-04
# Epoch 14/30
# 121/121 [==============================] - 1s 7ms/step - loss: 3.6225e-04 - val_loss: 4.2763e-04
# Epoch 15/30
# 121/121 [==============================] - 1s 7ms/step - loss: 3.3620e-04 - val_loss: 3.3099e-04
# Epoch 16/30
# 121/121 [==============================] - 1s 7ms/step - loss: 3.1886e-04 - val_loss: 3.3685e-04
# Epoch 17/30
# 121/121 [==============================] - 1s 7ms/step - loss: 3.0359e-04 - val_loss: 4.4785e-04
# Epoch 18/30
# 121/121 [==============================] - 1s 7ms/step - loss: 2.7275e-04 - val_loss: 2.7177e-04
# Epoch 19/30
# 121/121 [==============================] - 1s 6ms/step - loss: 2.8011e-04 - val_loss: 2.4159e-04
# Epoch 20/30
# 121/121 [==============================] - 1s 7ms/step - loss: 2.5094e-04 - val_loss: 3.0683e-04
# Epoch 21/30
# 121/121 [==============================] - 1s 7ms/step - loss: 2.3661e-04 - val_loss: 2.4400e-04
# Epoch 22/30
# 121/121 [==============================] - 1s 6ms/step - loss: 2.2903e-04 - val_loss: 2.0983e-04
# Epoch 23/30
# 121/121 [==============================] - 1s 7ms/step - loss: 2.1744e-04 - val_loss: 1.9918e-04
# Epoch 24/30
# 121/121 [==============================] - 1s 9ms/step - loss: 2.0650e-04 - val_loss: 1.8248e-04
# Epoch 25/30
# 121/121 [==============================] - 1s 9ms/step - loss: 1.9109e-04 - val_loss: 1.7525e-04
# Epoch 26/30
# 121/121 [==============================] - 1s 6ms/step - loss: 1.8984e-04 - val_loss: 1.7598e-04
# Epoch 27/30
# 121/121 [==============================] - 1s 7ms/step - loss: 2.0062e-04 - val_loss: 2.1888e-04
# Epoch 28/30
# 121/121 [==============================] - 1s 7ms/step - loss: 1.7992e-04 - val_loss: 1.4988e-04
# Epoch 29/30
# 121/121 [==============================] - 1s 6ms/step - loss: 1.7084e-04 - val_loss: 1.5117e-04
# Epoch 30/30
# 121/121 [==============================] - 1s 7ms/step - loss: 1.6216e-04 - val_loss: 1.7317e-04

# %%
# select overlapping 10-year windows
x = []
for n in range(time, length):
    x.append(temp_scaled[n-time:n, :])
x = np.array(x)

# make a prediction and unscale it
yp = scaler.inverse_transform(lmodel.predict(x))
# Out:
# 51/51 [==============================] - 0s 3ms/step

# %%
plt.plot(xaxis, temp_smooth, label='actual')
plt.plot(np.arange(1890, 2024, 1/12), yp, label='prediction')
plt.legend()
plt.xlabel('year')
plt.ylabel('global surface temperature change ($^{o}C$)')
plt.show()

# %%
first = (2016-1880)*12
temp_last = temp_scaled[first-time:first, :]
preds = []
for n in range(first, length):
    # make prediction
    pred = lmodel.predict(np.expand_dims(temp_last, 0), verbose=0)
    # append it to the sliding window
    temp_last = np.append(temp_last[1:, :], pred, axis=0)
    # save it in an array
    preds.append(pred[0])
# unscale the predictions
preds = scaler.inverse_transform(np.array(preds))

plt.plot(xaxis, temp_smooth, label='actual')
plt.plot(np.arange(2016, 2024, 1/12), preds, label='prediction')
plt.legend()
plt.xlabel('year')
plt.ylabel('global surface temperature change ($^{o}C$)')
plt.show()

# %% [markdown]
# ### Extending the model
#
# We can also try to improve the model by making it deeper.
#
# A deep model can not only add RNN layers but also use the ability to output whole sequences from the latent space.

# %% [markdown]
# ## <div style="color:red">Bonus Task</div>
#
# Test if making the model deeper improves its performance. Adjust the parameters if necessary.

# %%
from tensorflow.keras.layers import Dropout

lmodel2 = Sequential()
lmodel2.add(LSTM(12, return_sequences=True, input_shape=(time, 1)))
lmodel2.add(LSTM(12, return_sequences=True))
lmodel2.add(LSTM(12, return_sequences=False))

lmodel2.add(Dense(1))
lmodel2.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_2 (LSTM)               (None, 120, 12)           672
#
#  lstm_3 (LSTM)               (None, 120, 12)           1200
#
#  lstm_4 (LSTM)               (None, 12)                1200
#
#  dense_8 (Dense)             (None, 1)                 13
#
# =================================================================
# Total params: 3085 (12.05 KB)
# Trainable params: 3085 (12.05 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
lmodel2 = Sequential()
lmodel2.add(LSTM(12, input_shape=(time, 1)))
lmodel2.add(Dense(1))
lmodel.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, 12)                672
#
#  dense_7 (Dense)             (None, 1)                 13
#
# =================================================================
# Total params: 685 (2.68 KB)
# Trainable params: 685 (2.68 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
epochs = 30

lmodel2.compile(optimizer='adam', loss='mse')
fit = lmodel.fit(X, y, epochs=epochs, batch_size=12, validation_split=0.1)
# Out:
# Epoch 1/30
# 121/121 [==============================] - 1s 8ms/step - loss: 1.6175e-04 - val_loss: 1.3954e-04
# Epoch 2/30
# 121/121 [==============================] - 1s 7ms/step - loss: 1.5489e-04 - val_loss: 1.5918e-04
# Epoch 3/30
# 121/121 [==============================] - 1s 7ms/step - loss: 1.5521e-04 - val_loss: 1.2608e-04
# Epoch 4/30
# 121/121 [==============================] - 1s 6ms/step - loss: 1.4038e-04 - val_loss: 1.1871e-04
# Epoch 5/30
# 121/121 [==============================] - 1s 7ms/step - loss: 1.4377e-04 - val_loss: 1.2268e-04
# Epoch 6/30
# 121/121 [==============================] - 1s 7ms/step - loss: 1.3715e-04 - val_loss: 1.3657e-04
# Epoch 7/30
# 121/121 [==============================] - 1s 6ms/step - loss: 1.3148e-04 - val_loss: 1.4227e-04
# Epoch 8/30
# 121/121 [==============================] - 1s 7ms/step - loss: 1.2029e-04 - val_loss: 1.4030e-04
# Epoch 9/30
# 121/121 [==============================] - 1s 6ms/step - loss: 1.2081e-04 - val_loss: 1.1322e-04
# Epoch 10/30
# 121/121 [==============================] - 1s 6ms/step - loss: 1.2624e-04 - val_loss: 1.0953e-04
# Epoch 11/30
# 121/121 [==============================] - 1s 6ms/step - loss: 1.1118e-04 - val_loss: 1.2391e-04
# Epoch 12/30
# 121/121 [==============================] - 1s 6ms/step - loss: 1.1541e-04 - val_loss: 1.0362e-04
# Epoch 13/30
# 121/121 [==============================] - 1s 7ms/step - loss: 1.0881e-04 - val_loss: 9.8313e-05
# Epoch 14/30
# 121/121 [==============================] - 1s 9ms/step - loss: 1.0779e-04 - val_loss: 1.0599e-04
# Epoch 15/30
# 121/121 [==============================] - 1s 8ms/step - loss: 9.9040e-05 - val_loss: 1.0804e-04
# Epoch 16/30
# 121/121 [==============================] - 1s 6ms/step - loss: 1.0312e-04 - val_loss: 8.3201e-05
# Epoch 17/30
# 121/121 [==============================] - 1s 6ms/step - loss: 8.8999e-05 - val_loss: 1.1701e-04
# Epoch 18/30
# 121/121 [==============================] - 1s 6ms/step - loss: 8.7648e-05 - val_loss: 8.2017e-05
# Epoch 19/30
# 121/121 [==============================] - 1s 6ms/step - loss: 9.0430e-05 - val_loss: 7.4014e-05
# Epoch 20/30
# 121/121 [==============================] - 1s 6ms/step - loss: 8.7749e-05 - val_loss: 1.1153e-04
# Epoch 21/30
# 121/121 [==============================] - 1s 6ms/step - loss: 8.9033e-05 - val_loss: 1.0796e-04
# Epoch 22/30
# 121/121 [==============================] - 1s 7ms/step - loss: 8.6162e-05 - val_loss: 7.7690e-05
# Epoch 23/30
# 121/121 [==============================] - 1s 7ms/step - loss: 8.0234e-05 - val_loss: 7.3209e-05
# Epoch 24/30
# 121/121 [==============================] - 1s 7ms/step - loss: 8.2153e-05 - val_loss: 1.2450e-04
# Epoch 25/30
# 121/121 [==============================] - 1s 6ms/step - loss: 8.1930e-05 - val_loss: 6.4441e-05
# Epoch 26/30
# 121/121 [==============================] - 1s 7ms/step - loss: 8.5592e-05 - val_loss: 7.2750e-05
# Epoch 27/30
# 121/121 [==============================] - 1s 6ms/step - loss: 7.7534e-05 - val_loss: 6.8887e-05
# Epoch 28/30
# 121/121 [==============================] - 1s 8ms/step - loss: 7.7111e-05 - val_loss: 6.2934e-05
# Epoch 29/30
# 121/121 [==============================] - 1s 9ms/step - loss: 8.0161e-05 - val_loss: 6.7461e-05
# Epoch 30/30
# 121/121 [==============================] - 1s 7ms/step - loss: 7.6635e-05 - val_loss: 5.7505e-05

# %%
# select overlapping 10-year windows
x = []
for n in range(time, length):
    x.append(temp_scaled[n-time:n, :])
x = np.array(x)

# make a prediction and unscale it
yp = scaler.inverse_transform(lmodel2.predict(x))
# Out:
# 51/51 [==============================] - 1s 3ms/step

# %%
plt.plot(xaxis, temp_smooth, label='actual')
plt.plot(np.arange(1890, 2024, 1/12), yp, label='prediction')
plt.legend()
plt.xlabel('year')
plt.ylabel('global surface temperature change ($^{o}C$)')
plt.show()

# %%
first = (2016-1880)*12
temp_last = temp_scaled[first-time:first, :]
preds = []
for n in range(first, length):
    # make prediction
    pred = lmodel2.predict(np.expand_dims(temp_last, 0), verbose=0)
    # append it to the sliding window
    temp_last = np.append(temp_last[1:, :], pred, axis=0)
    # save it in an array
    preds.append(pred[0])
# unscale the predictions
preds = scaler.inverse_transform(np.array(preds))

plt.plot(xaxis, temp_smooth, label='actual')
plt.plot(np.arange(2016, 2024, 1/12), preds, label='prediction')
plt.legend()
plt.xlabel('year')
plt.ylabel('global surface temperature change ($^{o}C$)')
plt.show()

# %% [markdown]
# The first LSTM layer of the new network has the same configuration as before, but instead of outputting the final value of $\mathbf{h}_N$, it outputs the whole sequence $\mathbf{h}_1, \mathbf{h}_2 \ldots , \mathbf{h}_N$ to use it as an input to the next layer.

# %% [markdown]
# ## Transformers
#
# LSTM extends the power of prediction by looking at a longer context. However, the context remains limited. A radical departure from localized contexts is the idea of *transformers*, which revolutionized language analysis. Transformers absorb a wider context using the so-called *attention* mechanism.

# %% [markdown]
# ![](https://sebastianraschka.com/images/blog/2023/self-attention-from-scratch/paper.png)
#
# Vaswani, A., Shazeer, N., Parmar, N., Uszkoreit, J., Jones, L., Gomez, A.N., Kaiser, Ł. and Polosukhin, I., 2017. [Attention is all you need](https://proceedings.neurips.cc/paper_files/paper/2017/hash/3f5ee243547dee91fbd053c1c4a845aa-Abstract.html). Advances in neural information processing systems, 30.

# %% [markdown]
# Mathematically, attention is expressed with a simple formula
#
# $\text{Attention}(Q, K, V) = \displaystyle \text{softmax}\left(\frac{QK^\mathrm{T}}{\sqrt{d_k}}\right)V\;,$
#
# where $Q$, $K$, and $V$ (commonly known as *query*, *key*, and *value*) are matrices obtained by multiplying the input data by three weights ($W_Q$, $W_K$, and $W_V$), and $d_k$ corresponds to the dimension.

# %% [markdown]
# The illustrations below are borrowed from Jay Allamar: https://jalammar.github.io/illustrated-transformer/

# %% [markdown]
# ### Step 1: Generating $Q$, $K$, and $V$
#
# ![](https://jalammar.github.io/images/t/transformer_self_attention_vectors.png)

# %% [markdown]
# ### Step 2: Product of Q and K
#
# ![](https://jalammar.github.io/images/t/transformer_self_attention_score.png)

# %% [markdown]
# ### Step 3: Normalization and softmax
#
# ![](https://jalammar.github.io/images/t/self-attention_softmax.png)

# %% [markdown]
# ### Step 4: Multiplication by V
#
# ![](https://jalammar.github.io/images/t/self-attention-output.png)

# %% [markdown]
# ### Alltogether in a matrix form
#
# ![](https://jalammar.github.io/images/t/self-attention-matrix-calculation-2.png)
